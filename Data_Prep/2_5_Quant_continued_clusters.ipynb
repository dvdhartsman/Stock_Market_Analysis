# %% [markdown]
# # Continuation of Quantitative Analyst Project

# %% [markdown]
# ### Disclaimer: This notebook should not be considered any kind of financial advice. It exists only for the purposes of practicing modeling and making predictions

# %%
import yfinance as yf
from statsmodels.regression.rolling import RollingOLS
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import datetime as dt
import warnings
import pandas_ta
import statsmodels.api as sm
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", 25)
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/Users/samalainabayeva/Desktop/Capstone Project/stocks_for_modeling_clusters.csv')

# %%
df.shape
# Out:
# (13796, 23)

# %%
df.head(2)
# Out:
#                    Adj Close  garman_klass_vol        RSI  \
# Date       Ticker
# 2015-11-30 AAL     39.429935         -0.000966  40.880488
#            AAPL    26.960346         -0.003027  53.592898
#
#                    lowest_bollinger_band  lower_bollinger_band  20_day_SMA  \
# Date       Ticker
# 2015-11-30 AAL                 38.219863             39.883038   41.546214
#            AAPL                25.708802             26.310024   26.911246
#
#                    one_up_bollinger_band  upper_bollinger_band       ATR  \
# Date       Ticker
# 2015-11-30 AAL                 43.209389             44.872565  1.118944
#            AAPL                27.512468             28.113690  0.565622
#
#                        MACD  return_1m  return_2m  return_3m  return_6m  \
# Date       Ticker
# 2015-11-30 AAL    -0.656804  -0.105388   0.031926   0.019861  -0.003670
#            AAPL    0.161838  -0.005804   0.037844   0.017564  -0.014506
#
#                    return_9m  return_12m    Mkt-RF       SMB       HML  \
# Date       Ticker
# 2015-11-30 AAL     -0.015729   -0.012729  1.322942  0.910139  0.804086
#            AAPL    -0.007686    0.000966  1.084475 -0.136031 -0.397620
#
#                         RMW       CMA
# Date       Ticker
# 2015-11-30 AAL     1.222983 -0.061192
#            AAPL    0.718503 -0.795369

# %%
df.set_index(["Date", "Ticker"], inplace=True)

# %%
# this shows the 25th, 50th, 75th% of every day in our data, .quantile() can accept a list of quantiles
df.groupby("Date")['RSI'].quantile([0.25, 0.5, 0.75])
# Out:
# Date
# 2015-11-30  0.25    48.029423
#             0.50    53.325293
#             0.75    57.615866
# 2015-12-31  0.25    45.217133
#             0.50    48.891191
#                       ...
# 2023-09-30  0.50    44.088706
#             0.75    48.560172
# 2023-10-31  0.25    35.133633
#             0.50    41.029025
#             0.75    48.229785
# Name: RSI, Length: 288, dtype: float64

# %%
dates = df.index.get_level_values(0).unique()

# %% [markdown]
# I will now add a feature for which quartile of RSI a given stock is during a specific monthly period, with 4 being the top quartile, and 1 being the bottom quartile. The reason that we use RSI is that it is a momentum indicator, and therefore should contain signal about a stock's short term outlook.

# %% [markdown]
# ### Good function for creating quartile buckets, using the .cut() method

# %%
# Define a function to calculate quartiles

def calculate_quartiles(group):
    quartiles = group['RSI'].quantile([0.25, 0.5, 0.75])
    
    # pd.cut() is used to segment data, bins = -inf to .25, .25 to .5, .5 to .75, .75 to inf,
    # label "4" is the highest value group
    group['RSI_Quartile'] = pd.cut(group['RSI'], bins=[-float("inf")] + quartiles.to_list() + [float("inf")],\
                                   labels=[1, 2, 3, 4])
    return group

# %%
# Group by date and apply the quartile calculation function
quartile_df = df.groupby(level='Date', group_keys=False).apply(calculate_quartiles)

# %% [markdown]
# ### New df with buckets, that will likely be OHE candidates as well

# %%
quartile_df
# Out:
#                     Adj Close  garman_klass_vol        RSI  \
# Date       Ticker
# 2015-11-30 AAL      39.429935         -0.000966  40.880488
#            AAPL     26.960346         -0.003027  53.592898
#            ABBV     41.160294         -0.053947  46.995675
#            ABT      38.669395         -0.009962  52.539149
#            ACN      94.345917         -0.006636  57.567387
# ...                       ...               ...        ...
# 2023-10-31 VRTX    363.040009          0.000200  53.833235
#            VZ       33.689999          0.000221  58.946533
#            WFC      39.029999          0.000131  39.236461
#            WMT     162.759995          0.000062  55.397237
#            XOM     108.589996          0.000079  44.793090
#
#                    lowest_bollinger_band  lower_bollinger_band  20_day_SMA  \
# Date       Ticker
# 2015-11-30 AAL                 38.219863             39.883038   41.546214
#            AAPL                25.708802             26.310024   26.911246
#            ABBV                41.269060             42.342785   43.416509
#            ABT                 38.075918             38.510178   38.944438
#            ACN                 91.367418             92.512621   93.657824
# ...                                  ...                   ...         ...
# 2023-10-31 VRTX               344.018442            352.603220  361.187999
#            VZ                  29.828625             30.701467   31.574308
#            WFC                 38.205341             39.160670   40.116000
#            WMT                156.054002            158.010000  159.965999
#            XOM                104.273387            107.766443  111.259499
#
#                    one_up_bollinger_band  upper_bollinger_band       ATR  \
# Date       Ticker
# 2015-11-30 AAL                 43.209389             44.872565  1.118944
#            AAPL                27.512468             28.113690  0.565622
#            ABBV                44.490233             45.563957  1.753494
#            ABT                 39.378697             39.812957  0.739885
#            ACN                 94.803026             95.948229  1.288679
# ...                                  ...                   ...       ...
# 2023-10-31 VRTX               369.772778            378.357556  6.590981
#            VZ                  32.447150             33.319992  0.808540
#            WFC                 41.071329             42.026659  0.928127
#            WMT                161.921997            163.877996  2.215188
#            XOM                114.752555            118.245611  2.497244
#
#                        MACD  return_1m  return_2m  return_3m  return_6m  \
# Date       Ticker
# 2015-11-30 AAL    -0.656804  -0.105388   0.031926   0.019861  -0.003670
#            AAPL    0.161838  -0.005804   0.037844   0.017564  -0.014506
#            ABBV    0.411671  -0.023510   0.038557  -0.020296  -0.019629
#            ABT     0.405522   0.002679   0.059879  -0.000804  -0.011291
#            ACN     0.812790   0.000186   0.050196   0.047565   0.020338
# ...                     ...        ...        ...        ...        ...
# 2023-10-31 VRTX    4.149759   0.043998   0.020882   0.010022   0.010627
#            VZ      0.107031   0.061682  -0.008194   0.003209  -0.017041
#            WFC    -0.411437  -0.044787  -0.027753  -0.051934  -0.000449
#            WMT     0.245920   0.017695   0.000461   0.007201   0.013851
#            XOM    -1.027632  -0.076459  -0.011761   0.006915  -0.011464
#
#                    return_9m  return_12m    Mkt-RF       SMB       HML  \
# Date       Ticker
# 2015-11-30 AAL     -0.015729   -0.012729  1.322942  0.910139  0.804086
#            AAPL    -0.007686    0.000966  1.084475 -0.136031 -0.397620
#            ABBV    -0.001641   -0.011735  0.851106  0.279184  0.021886
#            ABT     -0.004146    0.002517  1.056769 -0.140064 -0.638172
#            ACN      0.022024    0.020034  1.143698 -0.203828 -0.181753
# ...                      ...         ...       ...       ...       ...
# 2023-10-31 VRTX     0.013034    0.012706  1.142086 -0.222391 -1.246586
#            VZ      -0.017064   -0.002729  0.669774 -0.389182 -0.140889
#            WFC     -0.017741   -0.011247  1.180862 -0.162028  1.280360
#            WMT      0.015090    0.012521  0.634972 -0.425805 -0.220643
#            XOM     -0.004615    0.001021  1.067910  0.286521  0.205092
#
#                         RMW       CMA RSI_Quartile
# Date       Ticker
# 2015-11-30 AAL     1.222983 -0.061192            1
#            AAPL    0.718503 -0.795369            3
#            ABBV   -0.269020 -0.043745            1
#            ABT     0.113359  0.560507            2
#            ACN     0.085237 -0.074808            3
# ...                     ...       ...          ...
# 2023-10-31 VRTX   -0.743384  0.918423            4
#            VZ      0.456590  1.195363            4
#            WFC    -0.628291 -0.298237            2
#            WMT     0.608535  0.533930            4
#            XOM    -0.376347  1.079449            3
#
# [13796 rows x 22 columns]

# %%
# As you can see, the respective quartile changes month to month

quartile_df.xs("NVDA", level=1)["RSI_Quartile"]
# Out:
# Date
# 2017-05-31    4
# 2017-06-30    3
# 2017-07-31    3
# 2017-08-31    3
# 2017-09-30    2
#              ..
# 2023-06-30    4
# 2023-07-31    3
# 2023-08-31    4
# 2023-09-30    3
# 2023-10-31    3
# Name: RSI_Quartile, Length: 78, dtype: category
# Categories (4, int64): [1 < 2 < 3 < 4]

# %%
quartile_df.index[0], quartile_df.index[-1]
# Out:
# (('2015-11-30', 'AAL'), ('2023-10-31', 'XOM'))

# %% [markdown]
# # Sector SPDR ETFs - processing for binary targets

# %%
spiders = pd.read_csv('/Users/samalainabayeva/Desktop/Capstone Project/SPDRs_w_technical_indicators.csv')

# %%
spiders.head()
# Out:
#          Date Ticker  Adj Close      Close       High        Low       Open  \
# 0  1998-12-22    XLB  12.011767  20.828125  20.828125  20.750000  20.781250
# 1  1998-12-22    XLE  12.448157  23.265625  23.390625  23.187500  23.312500
# 2  1998-12-22    XLF  11.612926  18.937855  19.052092  18.849005  19.052092
# 3  1998-12-22    XLI  14.971390  23.281250  23.281250  23.203125  23.203125
# 4  1998-12-22    XLK  24.243126  32.046875  32.500000  31.781250  32.406250
#
#      Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# 0    1900.0         -0.116068  NaN                    NaN
# 1   15200.0         -0.152028  NaN                    NaN
# 2   55887.0         -0.094617  NaN                    NaN
# 3     600.0         -0.074152  NaN                    NaN
# 4  300500.0         -0.032286  NaN                    NaN
#
#    lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# 0                   NaN         NaN                    NaN
# 1                   NaN         NaN                    NaN
# 2                   NaN         NaN                    NaN
# 3                   NaN         NaN                    NaN
# 4                   NaN         NaN                    NaN
#
#    upper_bollinger_band  ATR  MACD  dollar_volume(M)
# 0                   NaN  NaN   NaN            0.0228
# 1                   NaN  NaN   NaN            0.1892
# 2                   NaN  NaN   NaN            0.6490
# 3                   NaN  NaN   NaN            0.0090
# 4                   NaN  NaN   NaN            7.2851

# %%
# Everything is a float except for the Date and Ticker columns, which will both be made indexes
# RSI - Bollinger Bands - ATR - MACD all contain null values, likely will be dropped just to have complete data

spiders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59633 entries, 0 to 59632
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   59633 non-null  object
#  1   Ticker                 59633 non-null  object
#  2   Adj Close              59633 non-null  float64
#  3   Close                  59633 non-null  float64
#  4   High                   59633 non-null  float64
#  5   Low                    59633 non-null  float64
#  6   Open                   59633 non-null  float64
#  7   Volume                 59633 non-null  float64
#  8   garman_klass_vol       59633 non-null  float64
#  9   RSI                    59413 non-null  float64
#  10  lowest_bollinger_band  59424 non-null  float64
#  11  lower_bollinger_band   59424 non-null  float64
#  12  20_day_SMA             59424 non-null  float64
#  13  one_up_bollinger_band  59424 non-null  float64
#  14  upper_bollinger_band   59424 non-null  float64
#  15  ATR                    59479 non-null  float64
#  16  MACD                   59358 non-null  float64
#  17  dollar_volume(M)       59633 non-null  float64
# dtypes: float64(16), object(2)
# memory usage: 8.2+ MB

# %%
# Convert Date to date time

spiders["Date"] = pd.to_datetime(spiders["Date"])

# %%
spiders.set_index(["Date", "Ticker"], inplace=True)

# %%
spiders.head()
# Out:
#                    Adj Close      Close       High        Low       Open  \
# Date       Ticker
# 1998-12-22 XLB     12.011767  20.828125  20.828125  20.750000  20.781250
#            XLE     12.448157  23.265625  23.390625  23.187500  23.312500
#            XLF     11.612926  18.937855  19.052092  18.849005  19.052092
#            XLI     14.971390  23.281250  23.281250  23.203125  23.203125
#            XLK     24.243126  32.046875  32.500000  31.781250  32.406250
#
#                      Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# Date       Ticker
# 1998-12-22 XLB       1900.0         -0.116068  NaN                    NaN
#            XLE      15200.0         -0.152028  NaN                    NaN
#            XLF      55887.0         -0.094617  NaN                    NaN
#            XLI        600.0         -0.074152  NaN                    NaN
#            XLK     300500.0         -0.032286  NaN                    NaN
#
#                    lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date       Ticker
# 1998-12-22 XLB                      NaN         NaN                    NaN
#            XLE                      NaN         NaN                    NaN
#            XLF                      NaN         NaN                    NaN
#            XLI                      NaN         NaN                    NaN
#            XLK                      NaN         NaN                    NaN
#
#                    upper_bollinger_band  ATR  MACD  dollar_volume(M)
# Date       Ticker
# 1998-12-22 XLB                      NaN  NaN   NaN            0.0228
#            XLE                      NaN  NaN   NaN            0.1892
#            XLF                      NaN  NaN   NaN            0.6490
#            XLI                      NaN  NaN   NaN            0.0090
#            XLK                      NaN  NaN   NaN            7.2851

# %%
spiders.groupby("Date")

# %%
def 20_days_later(group):
    for row in group:
        current_index =

# %%
samp = spiders.sample(1)
# samp.index.get_loc(key="Date")

# %%
# A failed attempt to create binary columns

# sampled_row = spiders.sample(1)
# value_to_find = 'some_value'  # Replace with the value you want to find

# try:
#     index_location = sampled_row.index.get_loc(value_to_find)
#     print(f"The index location for '{value_to_find}' in the sampled row is: {index_location}")
# except KeyError:
#     print(f"'{value_to_find}' not found in the index of the sampled row.")
# Out:
# 'some_value' not found in the index of the sampled row.

# %%
# # Failed Experiments


# def create_return_binary_columns(df, intervals=[1, 3, 6, 12]):
#     for interval in intervals:
#         # Calculate the future date for the specified interval
#         future_date = df.index + pd.DateOffset(months=interval)
        
#         # Create a new column for future prices based on the calculated date
#         df[f'Price_{interval}M_Future'] = df.apply(lambda row: df.at[future_date, row.name[1]], axis=1)
        
#         # Create binary column: 1 if future price is higher, 0 otherwise
#         df[f'Price_{interval}M_Return'] = (df[f'Price_{interval}M_Future'] > df['Price']).astype(int)
        
#     return df

# # Example usage:
# # Assuming your DataFrame is indexed by date (level 0) and stock tickers (level 1) and has a 'Price' column.
# # df = ...

# # Create binary return columns for specified intervals
# binary_df = create_return_binary_columns(spiders, intervals=[1, 3, 6, 12])

# %%
spiders.head(2)
# Out:
#            Ticker  Adj Close      Close       High      Low      Open  \
# Date
# 1998-12-22    XLB  12.011767  20.828125  20.828125  20.7500  20.78125
# 1998-12-22    XLE  12.448157  23.265625  23.390625  23.1875  23.31250
#
#              Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# Date
# 1998-12-22   1900.0         -0.116068  NaN                    NaN
# 1998-12-22  15200.0         -0.152028  NaN                    NaN
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
#
#             upper_bollinger_band  ATR  MACD  dollar_volume(M)
# Date
# 1998-12-22                   NaN  NaN   NaN            0.0228
# 1998-12-22                   NaN  NaN   NaN            0.1892

# %% [markdown]
# ### Trying to develop an approach to creating new feature columns

# %%
# Start with a specific date
start_date = pd.to_datetime('2023-01-15')  # For example, January 15, 2023

# Calculate the date one business month later
one_month_later = start_date + pd.tseries.offsets.BMonthEnd(1)

print("Start Date:", start_date)
print("One Month Later (Business Days):", one_month_later)
# Out:
# Start Date: 2023-01-15 00:00:00
# One Month Later (Business Days): 2023-01-31 00:00:00

# %%
spiders.reset_index(inplace=True)

# %%
spiders['20_trading_days_later'] = spiders["Date"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59633 entries, 0 to 59632
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   59633 non-null  datetime64[ns]
#  1   Ticker                 59633 non-null  object
#  2   Adj Close              59633 non-null  float64
#  3   Close                  59633 non-null  float64
#  4   High                   59633 non-null  float64
#  5   Low                    59633 non-null  float64
#  6   Open                   59633 non-null  float64
#  7   Volume                 59633 non-null  float64
#  8   garman_klass_vol       59633 non-null  float64
#  9   RSI                    59413 non-null  float64
#  10  lowest_bollinger_band  59424 non-null  float64
#  11  lower_bollinger_band   59424 non-null  float64
#  12  20_day_SMA             59424 non-null  float64
#  13  one_up_bollinger_band  59424 non-null  float64
#  14  upper_bollinger_band   59424 non-null  float64
#  15  ATR                    59479 non-null  float64
#  16  MACD                   59358 non-null  float64
#  17  dollar_volume(M)       59633 non-null  float64
# dtypes: datetime64[ns](1), float64(16), object(1)
# memory usage: 8.2+ MB

# %% [markdown]
# ### Multi-Index Creation

# %%
spiders.set_index(["Date", "Ticker"], inplace=True)

# %%
for i in spiders.xs("XLB", level=1):
    print(type(i.index))
# Out:
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>
# <class 'builtin_function_or_method'>

# %%
spiders
# Out:
#             Date Ticker   Adj Close       Close        High         Low  \
# 0     1998-12-22    XLB   12.011767   20.828125   20.828125   20.750000
# 1     1998-12-22    XLE   12.448157   23.265625   23.390625   23.187500
# 2     1998-12-22    XLF   11.612926   18.937855   19.052092   18.849005
# 3     1998-12-22    XLI   14.971390   23.281250   23.281250   23.203125
# 4     1998-12-22    XLK   24.243126   32.046875   32.500000   31.781250
# ...          ...    ...         ...         ...         ...         ...
# 59628 2023-10-25    XLP   67.940002   67.940002   68.239998   67.419998
# 59629 2023-10-25   XLRE   32.189999   32.189999   32.650002   32.099998
# 59630 2023-10-25    XLU   59.349998   59.349998   59.470001   58.680000
# 59631 2023-10-25    XLV  126.510002  126.510002  127.459999  125.570000
# 59632 2023-10-25    XLY  150.389999  150.389999  152.550003  150.220001
#
#              Open      Volume  garman_klass_vol        RSI  \
# 0       20.781250      1900.0         -0.116068        NaN
# 1       23.312500     15200.0         -0.152028        NaN
# 2       19.052092     55887.0         -0.094617        NaN
# 3       23.203125       600.0         -0.074152        NaN
# 4       32.406250    300500.0         -0.032286        NaN
# ...           ...         ...               ...        ...
# 59628   67.599998  11351100.0          0.000063  43.174669
# 59629   32.540001   8454400.0          0.000099  33.847969
# 59630   58.919998  20654700.0          0.000069  46.305928
# 59631  127.070000  11427000.0          0.000104  37.148926
# 59632  152.289993   5600500.0          0.000058  34.756525
#
#        lowest_bollinger_band  lower_bollinger_band  20_day_SMA  \
# 0                        NaN                   NaN         NaN
# 1                        NaN                   NaN         NaN
# 2                        NaN                   NaN         NaN
# 3                        NaN                   NaN         NaN
# 4                        NaN                   NaN         NaN
# ...                      ...                   ...         ...
# 59628              66.122483             66.838991   67.555500
# 59629              32.120178             32.866839   33.613500
# 59630              56.095167             57.214334   58.333500
# 59631             126.420510            127.778756  129.137002
# 59632             150.750224            154.616362  158.482499
#
#        one_up_bollinger_band  upper_bollinger_band       ATR      MACD  \
# 0                        NaN                   NaN       NaN       NaN
# 1                        NaN                   NaN       NaN       NaN
# 2                        NaN                   NaN       NaN       NaN
# 3                        NaN                   NaN       NaN       NaN
# 4                        NaN                   NaN       NaN       NaN
# ...                      ...                   ...       ...       ...
# 59628              68.272008             68.988516  0.820658 -0.697945
# 59629              34.360161             35.106822  0.626503 -0.653811
# 59630              59.452666             60.571832  1.211284 -0.672943
# 59631             130.495248            131.853494  1.483988 -0.873242
# 59632             162.348636            166.214774  3.237231 -3.248586
#
#        dollar_volume(M)
# 0                0.0228
# 1                0.1892
# 2                0.6490
# 3                0.0090
# 4                7.2851
# ...                 ...
# 59628          771.1938
# 59629          272.1471
# 59630         1225.8564
# 59631         1445.6298
# 59632          842.2592
#
# [59633 rows x 18 columns]

# %%
spiders.reset_index(inplace=True)

# %% [markdown]
# ### Creating a list of the unique dates in the stock data

# %%
dates = spiders["Date"].unique()
dates
# Out:
# <DatetimeArray>
# ['1998-12-22 00:00:00', '1998-12-23 00:00:00', '1998-12-24 00:00:00',
#  '1998-12-28 00:00:00', '1998-12-29 00:00:00', '1998-12-30 00:00:00',
#  '1998-12-31 00:00:00', '1999-01-04 00:00:00', '1999-01-05 00:00:00',
#  '1999-01-06 00:00:00',
#  ...
#  '2023-10-12 00:00:00', '2023-10-13 00:00:00', '2023-10-16 00:00:00',
#  '2023-10-17 00:00:00', '2023-10-18 00:00:00', '2023-10-19 00:00:00',
#  '2023-10-20 00:00:00', '2023-10-23 00:00:00', '2023-10-24 00:00:00',
#  '2023-10-25 00:00:00']
# Length: 6251, dtype: datetime64[ns]

# %%
zero = spiders.loc[0]
zero["Date"]
# Out:
# Timestamp('1998-12-22 00:00:00')

# %%
# Draft, doesn't quite work

# def one_month_later(row):
#     dates = spiders["Date"].unique()
#     # Start with a specific date
#     start_date = row["Date"] 
    
#     # Calculate the date one month later, adjusting for weekends
#     one_month_later = start_date + pd.DateOffset(months=1)

#     # Check if the calculated date is a business day (Monday to Friday)
#     while one_month_later not in dates:  # 5 and 6 represent Saturday and Sunday
#         if one_month_later > dates[-1]:
#             row["one_month_later"] = np.nan
#         else:
#             one_month_later += pd.DateOffset(days=1)

#     row["one_month_later"] = one_month_later
#     return row

# %%
dates[-1]
# Out:
# Timestamp('2023-10-25 00:00:00')

# %%
(dates[-1] + pd.DateOffset(days=1))
# Out:
# Timestamp('2023-10-26 00:00:00')

# %%
spiders.loc[42, 'Date'] not in dates
# Out:
# False

# %% [markdown]
# ### Functions to create new features

# %%
# This group of functions works -> will revise later to repeat less

def one_month_later(date):
    dates = spiders["Date"].unique()
    # Start with a specific date
    start_date = date 
    
    # Calculate the date one month later, adjusting for weekends
    one_month_later = start_date + pd.DateOffset(months=1)

    while one_month_later not in dates:  
        if one_month_later > dates[-1]:
            return np.nan
            break
        else:
            one_month_later += pd.DateOffset(days=1)
    
    return one_month_later


def three_months_later(date):
    dates = spiders["Date"].unique()
    # Start with a specific date
    start_date = date 
    
    # Calculate the date one month later, adjusting for weekends
    one_month_later = start_date + pd.DateOffset(months=3)

    while one_month_later not in dates:  
        if one_month_later > dates[-1]:
            return np.nan
            break
        else:
            one_month_later += pd.DateOffset(days=1)
    
    return one_month_later


def six_months_later(date):
    dates = spiders["Date"].unique()
    # Start with a specific date
    start_date = date 
    
    # Calculate the date one month later, adjusting for weekends
    one_month_later = start_date + pd.DateOffset(months=6)

    while one_month_later not in dates:  
        if one_month_later > dates[-1]:
            return np.nan
            break
        else:
            one_month_later += pd.DateOffset(days=1)
    
    return one_month_later



def twelve_months_later(date):
    dates = spiders["Date"].unique()
    # Start with a specific date
    start_date = date 
    
    # Calculate the date one month later, adjusting for weekends
    one_month_later = start_date + pd.DateOffset(months=12)

    while one_month_later not in dates:  
        if one_month_later > dates[-1]:
            return np.nan
            break
        else:
            one_month_later += pd.DateOffset(days=1)
    
    return one_month_later

# %%
# Initialize these columns

spiders["one_month_later"] = 0
spiders["three_months_later"] = 0
spiders["six_months_later"] = 0
spiders["twelve_months_later"] = 0

# %%
spiders.head(2)
# Out:
#         Date Ticker  Adj Close      Close       High      Low      Open  \
# 0 1998-12-22    XLB  12.011767  20.828125  20.828125  20.7500  20.78125
# 1 1998-12-22    XLE  12.448157  23.265625  23.390625  23.1875  23.31250
#
#     Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# 0   1900.0         -0.116068  NaN                    NaN
# 1  15200.0         -0.152028  NaN                    NaN
#
#    lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# 0                   NaN         NaN                    NaN
# 1                   NaN         NaN                    NaN
#
#    upper_bollinger_band  ATR  MACD  dollar_volume(M)  one_month_later  \
# 0                   NaN  NaN   NaN            0.0228                0
# 1                   NaN  NaN   NaN            0.1892                0
#
#    three_months_later  six_months_later  twelve_months_later
# 0                   0                 0                    0
# 1                   0                 0                    0

# %%
# Checking data/type

spiders["Date"][0]
# Out:
# Timestamp('1998-12-22 00:00:00')

# %%
# showing that the function does work, January 22 1999 is one month later and is a date of observations

one_month_later(spiders["Date"][0])
# Out:
# Timestamp('1999-01-22 00:00:00')

# %% [markdown]
# ### Creating new feature for dates to be targetted

# %%
# Cell takes about 3 minutes to run

spiders['one_month_later'] = spiders["Date"].apply(one_month_later)
spiders["three_months_later"] = spiders["Date"].apply(three_months_later)
spiders["six_months_later"] = spiders["Date"].apply(six_months_later)
spiders["twelve_months_later"] = spiders["Date"].apply(twelve_months_later)

# %%
spiders.head()
# Out:
#         Date Ticker  Adj Close      Close       High        Low       Open  \
# 0 1998-12-22    XLB  12.011767  20.828125  20.828125  20.750000  20.781250
# 1 1998-12-22    XLE  12.448157  23.265625  23.390625  23.187500  23.312500
# 2 1998-12-22    XLF  11.612926  18.937855  19.052092  18.849005  19.052092
# 3 1998-12-22    XLI  14.971390  23.281250  23.281250  23.203125  23.203125
# 4 1998-12-22    XLK  24.243126  32.046875  32.500000  31.781250  32.406250
#
#      Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# 0    1900.0         -0.116068  NaN                    NaN
# 1   15200.0         -0.152028  NaN                    NaN
# 2   55887.0         -0.094617  NaN                    NaN
# 3     600.0         -0.074152  NaN                    NaN
# 4  300500.0         -0.032286  NaN                    NaN
#
#    lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# 0                   NaN         NaN                    NaN
# 1                   NaN         NaN                    NaN
# 2                   NaN         NaN                    NaN
# 3                   NaN         NaN                    NaN
# 4                   NaN         NaN                    NaN
#
#    upper_bollinger_band  ATR  MACD  dollar_volume(M) one_month_later  \
# 0                   NaN  NaN   NaN            0.0228      1999-01-22
# 1                   NaN  NaN   NaN            0.1892      1999-01-22
# 2                   NaN  NaN   NaN            0.6490      1999-01-22
# 3                   NaN  NaN   NaN            0.0090      1999-01-22
# 4                   NaN  NaN   NaN            7.2851      1999-01-22
#
#   three_months_later six_months_later twelve_months_later
# 0         1999-03-22       1999-06-22          1999-12-22
# 1         1999-03-22       1999-06-22          1999-12-22
# 2         1999-03-22       1999-06-22          1999-12-22
# 3         1999-03-22       1999-06-22          1999-12-22
# 4         1999-03-22       1999-06-22          1999-12-22

# %%
# Future Dates are date time objects

spiders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59633 entries, 0 to 59632
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   59633 non-null  datetime64[ns]
#  1   Ticker                 59633 non-null  object
#  2   Adj Close              59633 non-null  float64
#  3   Close                  59633 non-null  float64
#  4   High                   59633 non-null  float64
#  5   Low                    59633 non-null  float64
#  6   Open                   59633 non-null  float64
#  7   Volume                 59633 non-null  float64
#  8   garman_klass_vol       59633 non-null  float64
#  9   RSI                    59413 non-null  float64
#  10  lowest_bollinger_band  59424 non-null  float64
#  11  lower_bollinger_band   59424 non-null  float64
#  12  20_day_SMA             59424 non-null  float64
#  13  one_up_bollinger_band  59424 non-null  float64
#  14  upper_bollinger_band   59424 non-null  float64
#  15  ATR                    59479 non-null  float64
#  16  MACD                   59358 non-null  float64
#  17  dollar_volume(M)       59633 non-null  float64
#  18  one_month_later        59391 non-null  datetime64[ns]
#  19  three_months_later     58918 non-null  datetime64[ns]
#  20  six_months_later       58236 non-null  datetime64[ns]
#  21  twelve_months_later    56872 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), float64(16), object(1)
# memory usage: 10.0+ MB

# %% [markdown]
# # Re-establish the date as the index, try to create binary columns

# %%
spiders.set_index("Date", inplace=True)

# %%
spiders.head(2)
# Out:
#            Ticker  Adj Close      Close       High      Low      Open  \
# Date
# 1998-12-22    XLB  12.011767  20.828125  20.828125  20.7500  20.78125
# 1998-12-22    XLE  12.448157  23.265625  23.390625  23.1875  23.31250
#
#              Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# Date
# 1998-12-22   1900.0         -0.116068  NaN                    NaN
# 1998-12-22  15200.0         -0.152028  NaN                    NaN
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
#
#             upper_bollinger_band  ATR  MACD  dollar_volume(M) one_month_later  \
# Date
# 1998-12-22                   NaN  NaN   NaN            0.0228      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.1892      1999-01-22
#
#            three_months_later six_months_later twelve_months_later
# Date
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22

# %%
spiders.groupby("Ticker", group_keys=False)["Adj Close"].agg('mean')
# Out:
# Ticker
# XLB     34.733393
# XLC     57.960035
# XLE     40.074415
# XLF     17.709913
# XLI     41.127297
# XLK     45.314988
# XLP     31.292390
# XLRE    32.039864
# XLU     29.751282
# XLV     49.507054
# XLY     60.183651
# Name: Adj Close, dtype: float64

# %%
spiders.loc[dates[0], :]
# Out:
#            Ticker  Adj Close      Close       High        Low       Open  \
# Date
# 1998-12-22    XLB  12.011767  20.828125  20.828125  20.750000  20.781250
# 1998-12-22    XLE  12.448157  23.265625  23.390625  23.187500  23.312500
# 1998-12-22    XLF  11.612926  18.937855  19.052092  18.849005  19.052092
# 1998-12-22    XLI  14.971390  23.281250  23.281250  23.203125  23.203125
# 1998-12-22    XLK  24.243126  32.046875  32.500000  31.781250  32.406250
# 1998-12-22    XLP  14.967611  26.500000  26.531250  25.875000  25.875000
# 1998-12-22    XLU  12.582784  29.828125  30.250000  29.828125  30.250000
# 1998-12-22    XLV  17.505878  25.031250  25.062500  24.812500  24.812500
# 1998-12-22    XLY  19.151007  25.468750  25.468750  25.312500  25.312500
#
#               Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# Date
# 1998-12-22    1900.0         -0.116068  NaN                    NaN
# 1998-12-22   15200.0         -0.152028  NaN                    NaN
# 1998-12-22   55887.0         -0.094617  NaN                    NaN
# 1998-12-22     600.0         -0.074152  NaN                    NaN
# 1998-12-22  300500.0         -0.032286  NaN                    NaN
# 1998-12-22  150300.0         -0.115433  NaN                    NaN
# 1998-12-22    7900.0         -0.297125  NaN                    NaN
# 1998-12-22    5700.0         -0.046950  NaN                    NaN
# 1998-12-22    3700.0         -0.030038  NaN                    NaN
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
#
#             upper_bollinger_band  ATR  MACD  dollar_volume(M) one_month_later  \
# Date
# 1998-12-22                   NaN  NaN   NaN            0.0228      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.1892      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.6490      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.0090      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            7.2851      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            2.2496      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.0994      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.0998      1999-01-22
# 1998-12-22                   NaN  NaN   NaN            0.0709      1999-01-22
#
#            three_months_later six_months_later twelve_months_later  \
# Date
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
# 1998-12-22         1999-03-22       1999-06-22          1999-12-22
#
#             1-Month-Positive
# Date
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN
# 1998-12-22               NaN

# %%
spiders.rename(columns={"one_month_later":"one_months_later"}, inplace=True)

# %%
# First Draft, did not work in the end

# def one_month_gainer(df):
#     for ticker in list(df["Ticker"].unique()):
#         ticker_df = df[df["Ticker"] == ticker]
#         while ticker_df.loc[ticker_df["one_months_later"]]:
#             try:
#                 ticker_df["1_Month_Positive"] = (ticker_df["Adj Close"] < ticker_df.loc[ticker_df["one_month_later"], "Adj Close"])
#             except KeyError:
#                 pass

#         df.loc[df["Ticker"] == ticker, "1-Month-Positive"] = ticker_df["1_Month_Positive"]
    
#     return df

# %%
# This function works!!!!

def one_month_gainer(df, num="One"):
    for ticker in list(df["Ticker"].unique()):
        ticker_df = df[df["Ticker"] == ticker]

        for index, row in ticker_df.iterrows():
            try:
                one_month_later_value = row[f"{num.lower()}_months_later"]
                if not pd.isna(one_month_later_value):
                    ticker_df.at[index, f"{num}_Month_Positive"] = (row["Adj Close"] < ticker_df.loc[\
                                                                    one_month_later_value, "Adj Close"]).astype(int)
                else:
                    # Handle the case where one_month_later is NaN (NaT)
                    ticker_df.at[index, f"{num}_Month_Positive"] = np.nan
            except KeyError:
                # Handle the KeyError exception here if necessary
                ticker_df.at[index, f"{num}_Month_Positive"] = np.nan
           
        df.loc[df["Ticker"] == ticker, f"{num}_Month_Positive"] = ticker_df[f"{num}_Month_Positive"]
    
    return df

# %% [markdown]
# ###  Based on the above function

# %%
def three_month_gainer(df, num="Three"):
    return one_month_gainer(df, num)


def six_month_gainer(df, num="Six"):
    return one_month_gainer(df, num)


def twelve_month_gainer(df, num="Twelve"):
    return one_month_gainer(df, num)

# %%
# Looks like it is working as intended! 


bi_spiders = one_month_gainer(spiders)

# %%
bi_spiders.head(2)
# Out:
#            Ticker  Adj Close      Close       High      Low      Open  \
# Date
# 1998-12-22    XLB  12.011767  20.828125  20.828125  20.7500  20.78125
# 1998-12-22    XLE  12.448157  23.265625  23.390625  23.1875  23.31250
#
#              Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# Date
# 1998-12-22   1900.0         -0.116068  NaN                    NaN
# 1998-12-22  15200.0         -0.152028  NaN                    NaN
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
#
#             upper_bollinger_band  ATR  MACD  dollar_volume(M)  \
# Date
# 1998-12-22                   NaN  NaN   NaN            0.0228
# 1998-12-22                   NaN  NaN   NaN            0.1892
#
#            one_months_later three_months_later six_months_later  \
# Date
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
#
#            twelve_months_later  One_Month_Positive
# Date
# 1998-12-22          1999-12-22                 1.0
# 1998-12-22          1999-12-22                 0.0

# %%
# Adding the 3 month binary column

three_month_gainer(bi_spiders)
six_month_gainer(bi_spiders)
twelve_month_gainer(bi_spiders)
# Out:
#            Ticker   Adj Close       Close        High         Low        Open  \
# Date
# 1998-12-22    XLB   12.011767   20.828125   20.828125   20.750000   20.781250
# 1998-12-22    XLE   12.448157   23.265625   23.390625   23.187500   23.312500
# 1998-12-22    XLF   11.612926   18.937855   19.052092   18.849005   19.052092
# 1998-12-22    XLI   14.971390   23.281250   23.281250   23.203125   23.203125
# 1998-12-22    XLK   24.243126   32.046875   32.500000   31.781250   32.406250
# ...           ...         ...         ...         ...         ...         ...
# 2023-10-25    XLP   67.940002   67.940002   68.239998   67.419998   67.599998
# 2023-10-25   XLRE   32.189999   32.189999   32.650002   32.099998   32.540001
# 2023-10-25    XLU   59.349998   59.349998   59.470001   58.680000   58.919998
# 2023-10-25    XLV  126.510002  126.510002  127.459999  125.570000  127.070000
# 2023-10-25    XLY  150.389999  150.389999  152.550003  150.220001  152.289993
#
#                 Volume  garman_klass_vol        RSI  lowest_bollinger_band  \
# Date
# 1998-12-22      1900.0         -0.116068        NaN                    NaN
# 1998-12-22     15200.0         -0.152028        NaN                    NaN
# 1998-12-22     55887.0         -0.094617        NaN                    NaN
# 1998-12-22       600.0         -0.074152        NaN                    NaN
# 1998-12-22    300500.0         -0.032286        NaN                    NaN
# ...                ...               ...        ...                    ...
# 2023-10-25  11351100.0          0.000063  43.174669              66.122483
# 2023-10-25   8454400.0          0.000099  33.847969              32.120178
# 2023-10-25  20654700.0          0.000069  46.305928              56.095167
# 2023-10-25  11427000.0          0.000104  37.148926             126.420510
# 2023-10-25   5600500.0          0.000058  34.756525             150.750224
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
# ...                          ...         ...                    ...
# 2023-10-25             66.838991   67.555500              68.272008
# 2023-10-25             32.866839   33.613500              34.360161
# 2023-10-25             57.214334   58.333500              59.452666
# 2023-10-25            127.778756  129.137002             130.495248
# 2023-10-25            154.616362  158.482499             162.348636
#
#             upper_bollinger_band       ATR      MACD  dollar_volume(M)  \
# Date
# 1998-12-22                   NaN       NaN       NaN            0.0228
# 1998-12-22                   NaN       NaN       NaN            0.1892
# 1998-12-22                   NaN       NaN       NaN            0.6490
# 1998-12-22                   NaN       NaN       NaN            0.0090
# 1998-12-22                   NaN       NaN       NaN            7.2851
# ...                          ...       ...       ...               ...
# 2023-10-25             68.988516  0.820658 -0.697945          771.1938
# 2023-10-25             35.106822  0.626503 -0.653811          272.1471
# 2023-10-25             60.571832  1.211284 -0.672943         1225.8564
# 2023-10-25            131.853494  1.483988 -0.873242         1445.6298
# 2023-10-25            166.214774  3.237231 -3.248586          842.2592
#
#            one_months_later three_months_later six_months_later  \
# Date
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# ...                     ...                ...              ...
# 2023-10-25              NaT                NaT              NaT
# 2023-10-25              NaT                NaT              NaT
# 2023-10-25              NaT                NaT              NaT
# 2023-10-25              NaT                NaT              NaT
# 2023-10-25              NaT                NaT              NaT
#
#            twelve_months_later  One_Month_Positive  Three_Month_Positive  \
# Date
# 1998-12-22          1999-12-22                 1.0                   1.0
# 1998-12-22          1999-12-22                 0.0                   1.0
# 1998-12-22          1999-12-22                 0.0                   1.0
# 1998-12-22          1999-12-22                 1.0                   1.0
# 1998-12-22          1999-12-22                 1.0                   1.0
# ...                        ...                 ...                   ...
# 2023-10-25                 NaT                 NaN                   NaN
# 2023-10-25                 NaT                 NaN                   NaN
# 2023-10-25                 NaT                 NaN                   NaN
# 2023-10-25                 NaT                 NaN                   NaN
# 2023-10-25                 NaT                 NaN                   NaN
#
#             Six_Month_Positive  Twelve_Month_Positive
# Date
# 1998-12-22                 1.0                    1.0
# 1998-12-22                 1.0                    1.0
# 1998-12-22                 1.0                    1.0
# 1998-12-22                 1.0                    1.0
# 1998-12-22                 1.0                    1.0
# ...                        ...                    ...
# 2023-10-25                 NaN                    NaN
# 2023-10-25                 NaN                    NaN
# 2023-10-25                 NaN                    NaN
# 2023-10-25                 NaN                    NaN
# 2023-10-25                 NaN                    NaN
#
# [59633 rows x 25 columns]

# %%
bi_spiders.head(2)
# Out:
#            Ticker  Adj Close      Close       High      Low      Open  \
# Date
# 1998-12-22    XLB  12.011767  20.828125  20.828125  20.7500  20.78125
# 1998-12-22    XLE  12.448157  23.265625  23.390625  23.1875  23.31250
#
#              Volume  garman_klass_vol  RSI  lowest_bollinger_band  \
# Date
# 1998-12-22   1900.0         -0.116068  NaN                    NaN
# 1998-12-22  15200.0         -0.152028  NaN                    NaN
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 1998-12-22                   NaN         NaN                    NaN
# 1998-12-22                   NaN         NaN                    NaN
#
#             upper_bollinger_band  ATR  MACD  dollar_volume(M)  \
# Date
# 1998-12-22                   NaN  NaN   NaN            0.0228
# 1998-12-22                   NaN  NaN   NaN            0.1892
#
#            one_months_later three_months_later six_months_later  \
# Date
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
# 1998-12-22       1999-01-22         1999-03-22       1999-06-22
#
#            twelve_months_later  One_Month_Positive  Three_Month_Positive  \
# Date
# 1998-12-22          1999-12-22                 1.0                   1.0
# 1998-12-22          1999-12-22                 0.0                   1.0
#
#             Six_Month_Positive  Twelve_Month_Positive
# Date
# 1998-12-22                 1.0                    1.0
# 1998-12-22                 1.0                    1.0

# %%
# bi_spiders.drop(columns=["1-Month-Positive", "One-Month-Positive"], inplace=True)

# %% [markdown]
# ### Visually inspecting some random dates

# %%
spiders.loc["2010-09-03", :][:3]
# Out:
#            Ticker  Adj Close      Close       High        Low       Open  \
# Date
# 2010-09-03    XLB  24.445906  32.730000  32.750000  32.450001  32.599998
# 2010-09-03    XLE  34.812813  54.200001  54.439999  53.750000  54.029999
# 2010-09-03    XLF   9.235112  11.795288  11.795288  11.657189  11.705930
#
#                  Volume  garman_klass_vol        RSI  lowest_bollinger_band  \
# Date
# 2010-09-03    7809600.0         -0.031965  58.475407              22.523344
# 2010-09-03   13247100.0         -0.074554  54.335066              32.259655
# 2010-09-03  108976122.0         -0.021644  54.527284               8.393040
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 2010-09-03             23.042463   23.561582              24.080701
# 2010-09-03             33.139128   34.018601              34.898074
# 2010-09-03              8.646164    8.899289               9.152413
#
#             upper_bollinger_band       ATR      MACD  dollar_volume(M)  \
# Date
# 2010-09-03             24.599821  0.665356  0.104667          190.9127
# 2010-09-03             35.777547  1.108917 -0.159517          461.1688
# 2010-09-03              9.405537  0.240945 -0.072484         1006.4067
#
#            one_months_later three_months_later six_months_later  \
# Date
# 2010-09-03       2010-10-04         2010-12-03       2011-03-03
# 2010-09-03       2010-10-04         2010-12-03       2011-03-03
# 2010-09-03       2010-10-04         2010-12-03       2011-03-03
#
#            twelve_months_later  One_Month_Positive  Three_Month_Positive
# Date
# 2010-09-03          2011-09-06                 1.0                   1.0
# 2010-09-03          2011-09-06                 1.0                   1.0
# 2010-09-03          2011-09-06                 0.0                   1.0

# %%
bi_spiders.loc["2010-08-03", :][:3]
# Out:
#            Ticker  Adj Close      Close       High        Low       Open  \
# Date
# 2010-08-03    XLB  24.102339  32.270000  32.560001  32.200001  32.549999
# 2010-08-03    XLE  35.776260  55.700001  56.060001  55.240002  55.490002
# 2010-08-03    XLF   9.483160  12.112104  12.217709  12.095857  12.185215
#
#                 Volume  garman_klass_vol        RSI  lowest_bollinger_band  \
# Date
# 2010-08-03   9554200.0         -0.034813  58.020647              21.676848
# 2010-08-03  14254500.0         -0.074311  59.232019              32.829966
# 2010-08-03  81845251.0         -0.024230  54.170104               8.891043
#
#             lower_bollinger_band  20_day_SMA  one_up_bollinger_band  \
# Date
# 2010-08-03             22.430437   23.184027              23.937616
# 2010-08-03             33.536847   34.243729              34.950610
# 2010-08-03              9.075639    9.260234               9.444830
#
#             upper_bollinger_band       ATR      MACD  dollar_volume(M)  \
# Date
# 2010-08-03             24.691206  0.750625  0.460585          230.2786
# 2010-08-03             35.657492  1.237760  0.389115          509.9727
# 2010-08-03              9.629425  0.289780  0.072944          776.1516
#
#            one_months_later three_months_later six_months_later  \
# Date
# 2010-08-03       2010-09-03         2010-11-03       2011-02-03
# 2010-08-03       2010-09-03         2010-11-03       2011-02-03
# 2010-08-03       2010-09-03         2010-11-03       2011-02-03
#
#            twelve_months_later  One_Month_Positive  Three_Month_Positive
# Date
# 2010-08-03          2011-08-03                 1.0                   1.0
# 2010-08-03          2011-08-03                 0.0                   1.0
# 2010-08-03          2011-08-03                 0.0                   0.0

# %%
spiders[spiders["Ticker"] == "XLK"].loc[['1998-12-22', '1999-1-22'], "Adj Close"]
# Out:
# Date
# 1998-12-22    24.243126
# 1999-01-22    26.288010
# Name: Adj Close, dtype: float64

# %%
spiders["Ticker"]
# Out:
# Date
# 1998-12-22     XLB
# 1998-12-22     XLE
# 1998-12-22     XLF
# 1998-12-22     XLI
# 1998-12-22     XLK
#               ...
# 2023-10-25     XLP
# 2023-10-25    XLRE
# 2023-10-25     XLU
# 2023-10-25     XLV
# 2023-10-25     XLY
# Name: Ticker, Length: 59633, dtype: object

# %% [markdown]
# ### Checking out the value counts of the target variables

# %%
# Pretty good balance, which should help with training

bi_spiders["One_Month_Positive"].value_counts()
# Out:
# One_Month_Positive
# 1.0    35707
# 0.0    23684
# Name: count, dtype: int64

# %%
# Still pretty good balance (>2-1), which should help with training

bi_spiders["Three_Month_Positive"].value_counts()
# Out:
# Three_Month_Positive
# 1.0    38492
# 0.0    20426
# Name: count, dtype: int64

# %%
# Slightly more imbalanced

bi_spiders["Six_Month_Positive"].value_counts()
# Out:
# Six_Month_Positive
# 1.0    39697
# 0.0    18539
# Name: count, dtype: int64

# %%
# The most imbalanced, indicative of the long term uptrends in markets I suppose

bi_spiders["Twelve_Month_Positive"].value_counts()
# Out:
# Twelve_Month_Positive
# 1.0    41526
# 0.0    15346
# Name: count, dtype: int64

# %%
bi_spiders.index[0], bi_spiders.index[-1]
# Out:
# (Timestamp('1998-12-22 00:00:00'), Timestamp('2023-10-25 00:00:00'))

# %% [markdown]
# # Future to-dos

# %%
pd.to_datetime("2023-03-10 00:00:00") - pd.to_datetime('2023-01-29')
# Out:
# Timedelta('40 days 00:00:00')

# %%
spiders.head(1)
# Out:
#         Date Ticker  Adj Close      Close       High    Low      Open  Volume  \
# 0 1998-12-22    XLB  12.011767  20.828125  20.828125  20.75  20.78125  1900.0
#
#    garman_klass_vol  RSI  lowest_bollinger_band  lower_bollinger_band  \
# 0         -0.116068  NaN                    NaN                   NaN
#
#    20_day_SMA  one_up_bollinger_band  upper_bollinger_band  ATR  MACD  \
# 0         NaN                    NaN                   NaN  NaN   NaN
#
#    dollar_volume(M)
# 0            0.0228

# %%
# spiders.apply(one_month_later)

# %%
spiders.groupby("Ticker")["Adj Close"].apply(
# Out:
# 'Date        Ticker\n1998-12-22  XLB       12.011767\n1998-12-23  XLB       12.137930\n1998-12-24  XLB       12.417266\n1998-12-28  XLB       12.309141\n1998-12-29  XLB       12.534411\n                        ...    \n2023-10-19  XLB       76.220001\n2023-10-20  XLB       75.300003\n2023-10-23  XLB       74.459999\n2023-10-24  XLB       75.339996\n2023-10-25  XLB       74.459999\nName: XLB, Length: 6251, dtype: float64'

# %% [markdown]
# # This was all intended to be for clustering and unsupervised learning, but my kernel died every time I attempted to run the code

# %%
first_month = pd.read_csv('/Users/samalainabayeva/Desktop/Capstone Project/first_month_for_clusters.csv').set_index("Ticker")

# %%
first_month.describe()
# Out:
#          Adj Close  garman_klass_vol         RSI  lowest_bollinger_band  \
# count   132.000000        132.000000  132.000000             132.000000
# mean     80.912312         -0.016675   52.983209              77.146678
# std     127.120915          0.021141    7.348326             119.630251
# min       7.628457         -0.141608   34.720317               6.098736
# 25%      34.801295         -0.021135   48.029423              33.670969
# 50%      56.151548         -0.011600   53.325297              53.874267
# 75%      81.304329         -0.002884   57.615901              78.605980
# max    1248.849976          0.001324   74.285022            1158.433266
#
#        lower_bollinger_band   20_day_SMA  one_up_bollinger_band  \
# count            132.000000   132.000000             132.000000
# mean              79.358676    81.570674              83.782672
# std              126.567087   133.570306             140.629991
# min                7.453916     8.271838               8.534260
# 25%               34.185573    34.693648              35.263859
# 50%               55.044674    56.671385              57.669419
# 75%               79.786210    80.966440              81.928434
# max             1241.832887  1325.232507            1408.632128
#
#        upper_bollinger_band         ATR        MACD   return_1m   return_2m  \
# count            132.000000  132.000000  132.000000  132.000000  132.000000
# mean              85.994670    2.054617    0.072713    0.005862    0.044641
# std              147.738049    3.498124    3.688756    0.065844    0.045380
# min                8.796681    0.254239  -30.420512   -0.305013   -0.102977
# 25%               35.988396    0.838569   -0.023736   -0.020650    0.025159
# 50%               58.639578    1.336663    0.305626    0.007600    0.045585
# 75%               82.624958    2.014971    0.803474    0.034713    0.072823
# max             1492.031749   31.678713    6.815738    0.265952    0.139612
#
#         return_3m   return_6m   return_9m  return_12m      Mkt-RF         SMB  \
# count  132.000000  132.000000  132.000000  132.000000  132.000000  132.000000
# mean     0.015797   -0.004190   -0.001865    0.000671    1.074641    0.060857
# std      0.033860    0.029332    0.022660    0.020469    0.355909    0.468053
# min     -0.095143   -0.133946   -0.100787   -0.092039    0.363615   -0.757726
# 25%     -0.000159   -0.018923   -0.011457   -0.006870    0.884639   -0.309634
# 50%      0.017693   -0.001170    0.000944    0.000947    1.038932    0.050978
# 75%      0.035928    0.010741    0.010404    0.012554    1.218260    0.369028
# max      0.090324    0.075640    0.068660    0.079019    2.985178    1.447644
#
#               HML         RMW         CMA
# count  132.000000  132.000000  132.000000
# mean     0.109225   -0.087549    0.204366
# std      0.632350    0.753590    0.977439
# min     -1.413453   -2.987445   -2.137904
# 25%     -0.295009   -0.469367   -0.455296
# 50%      0.016935   -0.075542    0.120840
# 75%      0.494978    0.313979    0.710429
# max      1.837404    2.325522    3.780059

# %%
# Attempting to plot cluster metrics
silhouttes = []
inertias = []

for i in range(3, 5):
    clusters = KMeans(n_clusters=i, random_state=42, init='random')
    clusters.fit(first_month)
    silhouttes.append(silhouette_score(first_month, clusters.predict(first_month)))
    inertias.append(clusters.inertia_)
        
    
fig, ax = plt.subtplots(ncols=2, figsize=(16,6))
ax[0].plot(range(3,5), silhouttes)
ax[0].set_title("Silhoutte Scores for Various # of Clusters")

ax[1].plot(range(3,5), inertias)
ax[1].set_title("Inertia Plots")

# %%
# pd.read_csv('/Users/samalainabayeva/Desktop/Capstone Project/stocks_for_modeling_clusters').set_index(["Date", "Ticker"])

# %%
# Attempting to plot cluster metrics
silhouttes = []
inertias = []

# %%
clusters = KMeans(n_clusters=2, random_state=42, init='random')
clusters.fit(first_month)
silhouttes.append(silhouette_score(first_month, clusters.predict(first_month)))
inertias.append(clusters.inertia_)
